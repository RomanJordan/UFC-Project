# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_csv("Data/ufc/data.csv", delimiter=",")
rawData = pd.read_csv("Data/ufc/raw_fighter_details.csv", delimiter=",")
rawData.head(15)
# Out:
#        fighter_name  Height    Weight Reach    Stance           DOB
# 0        AJ Fonseca   5' 4"  145 lbs.   NaN       NaN           NaN
# 1       AJ Matthews  5' 11"  185 lbs.   NaN       NaN           NaN
# 2          AJ McKee  5' 10"  145 lbs.   NaN       NaN           NaN
# 3         AJ Siscoe   5' 7"  135 lbs.   NaN       NaN           NaN
# 4        Aalon Cruz   6' 0"  145 lbs.   NaN       NaN           NaN
# 5       Aaron Brink   6' 3"  205 lbs.   NaN  Orthodox  Nov 12, 1974
# 6         Aaron Ely   5' 8"  135 lbs.   NaN       NaN  Mar 18, 1989
# 7     Aaron Jeffery   6' 2"  185 lbs.   NaN       NaN  Nov 14, 1992
# 8   Aaron Lanfranco     NaN  155 lbs.   NaN       NaN  Aug 26, 1986
# 9      Aaron Miller   5' 9"  145 lbs.   NaN       NaN           NaN
# 10   Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11      Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12       Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# ...

# %%
rawData['fighter_name'] = rawData['fighter_name'].astype('str')
rawData['Weight'] = pd.to_numeric(rawData.Weight.str.replace('lbs.', ''), downcast='integer')

rawData.dtypes
# Out:
# fighter_name     object
# Height           object
# Weight          float64
# Reach            object
# Stance           object
# DOB              object
# dtype: object

# %%
data.date = pd.to_datetime(data.date)
data.dtypes
# Out:
# R_fighter                               object
# B_fighter                               object
# Referee                                 object
# date                            datetime64[ns]
# location                                object
# Winner                                  object
# title_bout                                bool
# weight_class                            object
# no_of_rounds                             int64
# B_current_lose_streak                  float64
# B_current_win_streak                   float64
# B_draw                                 float64
# B_avg_BODY_att                         float64
# B_avg_BODY_landed                      float64
# B_avg_CLINCH_att                       float64
# B_avg_CLINCH_landed                    float64
# B_avg_DISTANCE_att                     float64
# B_avg_DISTANCE_landed                  float64
# B_avg_GROUND_att                       float64
# B_avg_GROUND_landed                    float64
# ...

# %%
# How many fights per year
data['year'] = data['date'].dt.year
data.groupby(['year']).size()
# Out:
# year
# 1993      8
# 1994     29
# 1995     33
# 1996     36
# 1997     39
# 1998     20
# 1999     43
# 2000     41
# 2001     40
# 2002     53
# 2003     41
# 2004     39
# 2005     80
# 2006    158
# 2007    171
# 2008    201
# 2009    215
# 2010    253
# 2011    300
# 2012    341
# 2013    386
# 2014    503
# 2015    473
# 2016    493
# 2017    451
# 2018    474
# 2019    223
# dtype: int64

# %%
sns.set_style("darkgrid")
plt.plot(data.groupby(['year']).size())
plt.show()
